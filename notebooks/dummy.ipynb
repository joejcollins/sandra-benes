# %% [markdown]
# # Dummy Notebook
#
# Doing something dumb.

# %%
"""Dummy helper demonstration."""
from sandra_benes.helpers import dummy_helper

new_number = dummy_helper.add_things(1, 2)

print(new_number)
# Out:
# 2025-08-19 14:38:19.268 | INFO     | sandra_benes.config:<module>:20 - PROJ_ROOT path is: /Users/joe/Documents/Projects/sandra-benes
# 3

# %% [markdown]
# # Dummy Plot
#
# Yes, it's dumb.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 20]

# Create a line plot
plt.plot(x, y, marker='o')
plt.title('Sample Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.show()
